# %%
import import_ipynb
import Malaria_DataCleaning
# %run ../Malaria_DataCleaning/Malaria_DataCleaning.ipynb
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/Documents/Python/Projects/Malaria_EDA/Malaria_DataCleaning/Malaria_DataCleaning.ipynb in <module>
#       2 est_cases_master = pd.read_csv('~/Documents/Python/Projects/Malaria_EDA/Malaria_DataCleaning/Data/WHO/cases/malaria_estimated_cases.csv', skiprows=1)
#       3 #est_cases_master = pd.read_csv('Data/WHO/cases/malaria_estimated_cases.csv', skiprows=1)
# ----> 4 inc_cases =  pd.read_csv('Data/WHO/cases/malaria_case_incidence_per_1000_pop_at_risk.csv', skiprows=1)
#       5 countries_WHO_region = pd.read_csv('Data/countries.csv')
#       6 #reorder columns
#
# ...

# %%
import plotly.express as px
from matplotlib import pyplot as plt
import pandas as pd

# %%
fig1 = px.pie(WHO_region, values='2017', names='WHO_Region',
             title='Percentage of Worldwide Cases by WHO Region in 2017')
fig1.write_image("../Malaria_Graphs/Figures/pie/MalariaCasesPerc2017_WHOregion.jpg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-35986d438ae9> in <module>
# ----> 1 fig1 = px.pie(WHO_region, values='2017', names='WHO_Region',
#       2              title='Percentage of Worldwide Cases by WHO Region in 2017')
#       3 fig1.write_image("../Malaria_Graphs/Figures/pie/MalariaCasesPerc2017_WHOregion.jpg")
#
# NameError: name 'WHO_region' is not defined

# %%
fig2 = px.bar(WHO_region_pivot,
              x='Year',
              y=WHO_region_pivot.columns.tolist()[1:],
              title='Worldwide Cases of Malaria',
              labels={'value':'Malaria Cases (million people)',
                      'variable':'WHO Region'})
fig2.write_image('../Malaria_Graphs/Figures/bar/MalariaCases2010_2017_WHOregion.jpg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-292dd0574934> in <module>
# ----> 1 fig2 = px.bar(WHO_region_pivot,
#       2               x='Year',
#       3               y=WHO_region_pivot.columns.tolist()[1:],
#       4               title='Worldwide Cases of Malaria',
#       5               labels={'value':'Malaria Cases (million people)',
#
# NameError: name 'WHO_region_pivot' is not defined
